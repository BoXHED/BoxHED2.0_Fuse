# %% [markdown]
# # Notes Report
# This report will answer:
# 1. What do the notes contain? -- How do they differ structurally? Semantically?
# 2. Statistical info about the note category. Token count? Note count per icustay?
# 3. Statistical comparison between categories

# %%
import pandas as pd
rad_path = f'/data/datasets/mimiciv_notes/physionet.org/files/mimic-iv-note/2.2/note/radiology.csv'
dis_path = f'/data/datasets/mimiciv_notes/physionet.org/files/mimic-iv-note/2.2/note/discharge.csv'
mimic_iii_noteevents_path = '/data/datasets/mimiciv_notes/mimiciii_notes/physionet.org/files/mimiciii/1.4/NOTEEVENTS.csv'
train_rad_cohort_path = f'/home/ugrads/a/aa_ron_su/BoXHED_Fuse/BoXHED_Fuse/JSS_SUBMISSION_NEW/data/targets/till_end_mimic_iv_extra_features_train_NOTE_TARGET_2_rad_recent.csv'
test_rad_cohort_path = f'/home/ugrads/a/aa_ron_su/BoXHED_Fuse/BoXHED_Fuse/JSS_SUBMISSION_NEW/data/targets/till_end_mimic_iv_extra_features_test_NOTE_TARGET_2_rad_recent.csv'
train_dis_cohort_path = f'/home/ugrads/a/aa_ron_su/BoXHED_Fuse/BoXHED_Fuse/JSS_SUBMISSION_NEW/data/targets/till_end_mimic_iv_extra_features_train_NOTE_TARGET_2_dis_recent.csv'
test_dis_cohort_path = f'/home/ugrads/a/aa_ron_su/BoXHED_Fuse/BoXHED_Fuse/JSS_SUBMISSION_NEW/data/targets/till_end_mimic_iv_extra_features_test_NOTE_TARGET_2_dis_recent.csv'

# %%
train_rad_c_df = pd.read_csv(train_rad_cohort_path)
test_rad_c_df = pd.read_csv(test_rad_cohort_path)

# %%
18745/ len(distr)
# Out:
# 0.6918761303657771

# %%
distr = train_rad_c_df.groupby('ICUSTAY_ID').delta_in_2_days.sum()
distr.value_counts()
# Out:
# 0     18745
# 1      6177
# 2      1248
# 3       393
# 4       215
# 5       145
# 6        81
# 7        40
# 8        24
# 9         8
# 11        7
# 10        4
# 12        2
# 14        1
# 18        1
# 13        1
# 19        1
# Name: delta_in_2_days, dtype: int64

# %%
len(train_rad_c_df), len(test_rad_c_df), len(train_rad_c_df) + len(test_rad_c_df)
# Out:
# (76148, 18470, 94618)

# %%
train_dis_c_df = pd.read_csv(train_dis_cohort_path)
test_dis_c_df = pd.read_csv(test_dis_cohort_path)

# %%
len(train_dis_c_df), len(test_dis_c_df), len(train_dis_c_df) + len(test_dis_c_df)
# Out:
# (14573, 2582, 17155)

# %%
# mimic_iii_noteevents = pd.read_csv(mimic_iii_noteevents_path)
radiology = pd.read_csv(rad_path)
discharge = pd.read_csv(dis_path)

# %%
radiology
# Out:
#                 note_id  subject_id     hadm_id note_type  note_seq  \
# 0        10000032-RR-14    10000032  22595853.0        RR        14
# 1        10000032-RR-15    10000032  22595853.0        RR        15
# 2        10000032-RR-16    10000032  22595853.0        RR        16
# 3        10000032-RR-18    10000032         NaN        RR        18
# 4        10000032-RR-20    10000032         NaN        RR        20
# ...                 ...         ...         ...       ...       ...
# 2321350  19999987-RR-17    19999987  23865745.0        RR        17
# 2321351  19999987-RR-18    19999987  23865745.0        RR        18
# 2321352  19999987-RR-19    19999987  23865745.0        RR        19
# 2321353  19999987-RR-20    19999987  23865745.0        RR        20
# 2321354  19999987-RR-21    19999987  23865745.0        RR        21
#
#                    charttime            storetime  \
# 0        2180-05-06 21:19:00  2180-05-06 23:32:00
# ...

# %%
mimic_iii_noteevents[mimic_iii_noteevents.category == 'Nursing/other']

# %%
len(mimic_iii_noteevents), len(radiology), len(discharge)
# Out:
# (2083180, 2321355, 331794)

# %%
(len(discharge)  + len(radiology)) / len(mimic_iii_noteevents)
# Out:
# 1.2736052573469407

# %% [markdown]
# # What's the difference between mimic_iii and mimic_iv notes?
#
# num categories?
# num notes?
# uhhhhh
#
# frequency??

# %%
mimic_iii_noteevents.DESCRIPTION.value_counts()[:50]

# %%
radiology[radiology.note_type == 'AR']

# %%
mimic_iii_noteevents.CATEGORY.value_counts()
# Out:
# Nursing/other        822497
# Radiology            522279
# Nursing              223556
# ECG                  209051
# Physician            141624
# Discharge summary     59652
# Echo                  45794
# Respiratory           31739
# Nutrition              9418
# General                8301
# Rehab Services         5431
# Social Work            2670
# Case Management         967
# Pharmacy                103
# Consult                  98
# Name: CATEGORY, dtype: int64

# %%
radiology['hadm_id'].value_counts().mean()
# Out:
# 3.696702941841315

# %%
discharge['hadm_id'].value_counts().mean()
# Out:
# 1.0

# %%
mimic_iii_noteevents['HADM_ID'].value_counts().mean()
# Out:
# 31.722280289919638

# %%
mimic_iii_noteevents[mimic_iii_noteevents['SUBJECT_ID'] == 55672]

# %%
import matplotlib.pyplot as plt

# Data
categories = ['Nursing/Other', 'Radiology', 'Nursing', 'ECG', 'Physician', 
              'Discharge Summary', 'Echo', 'Respiratory', 'Other']

counts = [822497, 522279, 223556, 209051, 141624, 59652, 45794, 31739, 
          9418 + 8301 + 5431 + 2670 + 1168]  
          
explode = [0 if category not in ['Radiology', 'Discharge Summary'] else 0.1 for category in categories]


# Plot
plt.figure(figsize=(6, 6))
pie = plt.pie(counts, rotatelabels=True, explode=explode, labels=categories, autopct=lambda p: '{:.1f}%'.format(p) if p > 1 else '', startangle=140, labeldistance=1.0)
plt.axis('equal')
plt.title('Distribution of MIMIC III Note Types', pad=60)
plt.show()


categories = ['Radiology', 'Discharge Summary']

counts = [len(radiology), len(discharge)]  
          


# Plot
plt.figure(figsize=(6, 6))
pie = plt.pie(counts, rotatelabels=True, labels=categories, autopct=lambda p: '{:.1f}%'.format(p) if p > 1 else '', startangle=140, labeldistance=1.0)
plt.axis('equal')
plt.title('Distribution of MIMIC III Note Types', pad=60)
plt.show()

# %%
len(radiology), len(discharge)
# Out:
# (2321355, 331794)

# %%
import matplotlib.pyplot as plt

# Data
categories = ['Radiology', 'Discharge Summary']

counts = [len(radiology), len(discharge)]  
          


# Plot
plt.figure(figsize=(6, 6))
pie = plt.pie(counts, rotatelabels=True, labels=categories, autopct=lambda p: '{:.1f}%'.format(p) if p > 1 else '', startangle=140, labeldistance=1.0)
plt.axis('equal')
plt.title('Distribution of MIMIC III Note Types', pad=60)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
categories1 = ['Radiology','Discharge Summary','Nursing/Other', 'Nursing', 'ECG', 'Physician', 
             'Echo', 'Respiratory', 'Other']

counts1 = [522279,59652,822497, 223556, 209051, 141624, 45794, 31739, 
           9418 + 8301 + 5431 + 2670 + 1168]

explode1 = [0 if category not in ['Radiology', 'Discharge Summary'] else 0.05 for category in categories1]

categories2 = ['Radiology', 'Discharge Summary']

counts2 = [len(radiology), len(discharge)]

# Plot
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot first pie chart
axes[0].pie(counts1, rotatelabels=True, explode=explode1, labels=categories1, autopct=lambda p: '{:.1f}%'.format(p) if p > 1 else '', startangle=140, labeldistance=1.0)
axes[0].set_title('Distribution of MIMIC III Notes', pad=60, fontsize=14)

# Plot second pie chart
axes[1].pie(counts2, rotatelabels=True, labels=categories2, autopct=lambda p: '{:.1f}%'.format(p) if p > 1 else '', startangle=140, labeldistance=1.0)
axes[1].set_title('Distribution of MIMIC IV Notes', pad=60, fontsize=14)

plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
rad_cohort_path_og = f'/home/ugrads/a/aa_ron_su/BoXHED_Fuse/BoXHED_Fuse/JSS_SUBMISSION_NEW/data/till_end_mimic_iv_extra_features_train.csv'
og_rad_c_df = pd.read_csv(rad_cohort_path_og)

# %%
og_rad_c_df_view = og_rad_c_df[['Icustay','subject',]]
og_rad_c_df_view.rename(columns={'subject': 'SUBJECT_ID', 'Icustay':'ICUSTAY_ID'}, inplace=True)
# Out:
# /tmp/ipykernel_1337171/112213318.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   og_rad_c_df_view.rename(columns={'subject': 'SUBJECT_ID', 'Icustay':'ICUSTAY_ID'}, inplace=True)

# %%
og_rad_c_df_view.ICUSTAY_ID.nunique(), rad_c_df.ICUSTAY_ID.nunique()
# Out:
# (30716, 27093)

# %%
27093/30716
# Out:
# 0.8820484438077875

# %%
notes = og_rad_c_df[~ og_rad_c_df.NOTE_ID.isin(rad_c_df.NOTE_ID)].NOTE_ID.unique()
notes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 notes = og_rad_c_df[~ og_rad_c_df.NOTE_ID.isin(rad_c_df.NOTE_ID)].NOTE_ID.unique()
#       2 notes
#
# File ~/miniconda3/envs/clinical1/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'NOTE_ID'

# %%
subj_note_view = og_rad_c_df[~og_rad_c_df.NOTE_ID.isin(rad_c_df.NOTE_ID)][['NOTE_ID', 'SUBJECT_ID']].groupby('NOTE_ID').count()
subj_note_view
# Out:
#                 SUBJECT_ID
# NOTE_ID
# 10393331-RR-21           9
# 10667727-RR-21          67
# 10956880-RR-9            6
# 11196689-RR-19           5
# 12557579-RR-17          32
# 12710598-RR-17          12
# 12954060-RR-14          15
# 14124344-RR-77          39
# 16497039-RR-39          17
# 17856327-RR-23           2

# %%
og_rad_c_df[~og_rad_c_df.NOTE_ID.isin(rad_c_df.NOTE_ID)].SUBJECT_ID.nunique()
# Out:
# 4329

# %% [markdown]
# ## 1. What do the notes contain?

# %% [markdown]
# The discharge table contains discharge summaries for hospitalizations. Discharge summaries are long form narratives which describe the reason for a patient’s admission to the hospital, their hospital course, and any relevant discharge instructions.
#
# The radiology table contains free-text radiology reports associated with radiography imaging. Radiology reports cover a variety of imaging modalities: x-ray, computed tomography, magnetic resonance imaging, ultrasound, and so on. Free-text radiology reports are semi-structured and usually follow a consistent template for a given imaging protocol

# %%
import numpy as np

np.random.seed(1)
n = rad_c_df.shape[0]
idxs = [np.random.randint(n) for _ in range(3)]

# print(rad_c_df.iloc[idxs[0]].text)
# print( '-' * 40)
'''
HISTORY
FINDINGS
'''

# print(rad_c_df.iloc[idxs[1]].text)
# print( '-' * 40)
'''
INDICATION
COMPARISON
TECHNIQUE
FINDINGS
IMPRESSION
'''

# print(rad_c_df.iloc[idxs[2]].text)
# print( '-' * 40)
'''
EXAMINATION
INDICATION
DOSE
COMPARISON
FINDINGS
Head_CTA
IMPRESSION
'''
# Out:
# '\nEXAMINATION\nINDICATION\nDOSE\nCOMPARISON\nFINDINGS\nHead_CTA\nIMPRESSION\n'

# %% [markdown]
# Radiology is structured with headings in all caps. These vary in type, but generally there is some form of imaging performed followed by findings, impression, comparison, etc.

# %%
import numpy as np

np.random.seed(1)
n = dis_c_df.shape[0]
idxs = [np.random.randint(n) for _ in range(3)]

# print(dis_c_df.iloc[idxs[0]].text)
# print( '-' * 40)
'''
personal info... (hidden data for privacy)
  Service: Neurosurgery
  Chief Complaint: Fall
  Major Surgical or Invasive Procedure: None
  Name:  ___.           Unit No:   ___
  Admission Date:  ___              Discharge Date:   ___
  Date of Birth:  ___             Sex:   M
  ...
Service: NEUROSURGERY
Chief Complaint:
Major Surgical or Invasive Procedure:
History of Present Illness:
Past Medical History:
Social History:
Family History:
Physical Exam: 

On Discharge: 
Pertinent Results:
CT Head:
IMPRESSION: 

Brief Hospital Course:
Medications on Admission:
Discharge Medications: 
Discharge Disposition: 
Discharge Diagnosis:
Discharge Condition:
Discharge Instructions: 
Followup Instructions:
'''

# print(dis_c_df.iloc[idxs[1]].text)
# print( '-' * 40)
'''
personal info...
Chief Complaint:
Major Surgical or Invasive Procedure:
History of Present Illness:
Review of sytems:  
Past Medical History:
Social History:
Family History:
Physical Exam: 

GU: no foley  
Ext: 
Neuro: 
Pertinent Results:
Alpha-1 antitrypsin level: 31
Alpha-1 antitrypsin phenotype:
MICROBIOLOGY:
IMAGING:

Brief Hospital Course:
#. Ascitic fluid leakage: 
#. Cirrhosis: 
#. Pneumonia: 
Medications on Admission:
Discharge Medications:
Discharge Disposition:
Discharge Diagnosis:
Discharge Condition:
Discharge Instructions:
Followup Instructions:
'''

# print(dis_c_df.iloc[idxs[2]].text)
# print( '-' * 40)
'''
----------------------------------------
----------------------------------------
 
personal info...
Chief Complaint:
Major Surgical or Invasive Procedure:
History of Present Illness:
Past Medical History:
Social History:
Family History:
Physical Exam:

CT ABDOMEN W/O CONTRAST Study Date of ___ 1:14 ___ 
CT HEAD W/O CONTRAST Study Date of ___ 10:___vidence of acute intracranial process.  Chronic changes 
CT ABD & PELVIS W/O CONTRAST Study Date of ___ 4:09 ___ 
CT CHEST W/O CONTRAST Study Date of ___ 4:23 ___ 
CT ABD & PELVIS W/O CONTRAST Study Date of ___ 10:56 ___ 

Brief Hospital Course:
Medications on Admission:
Discharge Medications:
Discharge Disposition:
Facility:
Discharge Diagnosis:
Discharge Condition:
Discharge Instructions:
Followup Instructions:
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       1 import numpy as np
#       3 np.random.seed(1)
# ----> 4 n = dis_c_df.shape[0]
#       5 idxs = [np.random.randint(n) for _ in range(3)]
#       7 # print(dis_c_df.iloc[idxs[0]].text)
#       8 # print( '-' * 40)
#
# NameError: name 'dis_c_df' is not defined

# %% [markdown]
# ## 2. Statistical info about the note category.
# Token count? Note count per icustay?

# %%
import sys
import os
sys.path.append("/home/ugrads/a/aa_ron_su")
# from BoXHED_Fuse.src.helpers import tokenization

from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('../models/Clinical-T5-Base/')

# %%
def tokenization(tokenizer, batched_text):
    return tokenizer(batched_text['text'], padding = False, truncation=False)

# %%
from functools import partial
from datasets import Dataset
rad_c_ds = Dataset.from_pandas(rad_c_df).select_columns(['text'])
tokens_rad = rad_c_ds.map(partial(tokenization, tokenizer), batched = True, batch_size = len(rad_c_ds) // 10)

dis_c_ds = Dataset.from_pandas(dis_c_df).select_columns(['text'])
tokens_dis = dis_c_ds.map(partial(tokenization, tokenizer), batched = True, batch_size = len(dis_c_ds) // 10)
# Out:
# Map:   0%|          | 0/76148 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (608 > 512). Running this sequence through the model will result in indexing errors
# Map:   0%|          | 0/14573 [00:00<?, ? examples/s]

# %%
note_token_lens_rad = [len(t['input_ids']) for t in tokens_rad]
note_token_lens_dis = [len(t['input_ids']) for t in tokens_dis]

# %%
def summary_stats(data):
    print(f'MEAN: {np.mean(data)}\nMEDIAN: {np.median(data)},\nMAX: {np.max(data)}\nMIN: {np.min(data)}')

summary_stats(note_token_lens_rad)
summary_stats(note_token_lens_dis)
# Out:
# MEAN: 265.7898828596943
# MEDIAN: 179.0,
# MAX: 3298
# MIN: 5
# MEAN: 3368.4673025458037
# MEDIAN: 3191.0,
# MAX: 16248
# MIN: 256

# %% [markdown]
# Radiology reports are more succinct. With an average token length of 265, their information easily fits into a 512 token transformer input.
# On the other hand, discharge notes are much longer at > 3000 tokens on average and will need to be truncated.

# %%
print(tokens_rad[int(np.argmin(note_token_lens_rad))]['text'])
print(tokens_dis[int(np.argmin(note_token_lens_dis))]['text'])
# Out:
# agree with reading.
#
#
#
# Name:  ___                   Unit No:   ___
#
# Admission Date:  ___              Discharge Date:   ___
#
# Date of Birth:  ___             Sex:   F
#
# Service: SURGERY
#
# Allergies:
# No Drug Allergy Information on File
#
# Attending: ___.
#
# Chief Complaint:
# s/p fall
#
# Major Surgical or Invasive Procedure:
# None
#
#
# Brief Hospital Course:
# Ms. ___ is a ___ who sustained a fall at home.  She was
# found to have a large acute on chronic subdural hematoma with
# extensive midline shift and herniation.  Her clinical exam
# revealed no brain stem reflexes.  She was evaulated by
# neurosurgery who deemed the injury to severe to perform emergent
# surgical decompression.  A family meeting was had and they
# elected to make her CMO.  She was extubated and expired shortly
# thereafter.
#
# Discharge Disposition:
# Expired
#
# Discharge Diagnosis:
# Traumatic acute on chronic subdural hematoma
# Respiratory Failure
#
#
# Discharge Condition:
# Expired
# ...

# %%
print(tokens_rad[int(np.argmax(note_token_lens_rad))]['text'])
print(tokens_dis[int(np.argmax(note_token_lens_dis))]['text'])
# Out:
# ANGIOGRAPHY AND INTERVENTIONAL REPORT
#
# CLINICAL HISTORY:  Patient is a ___ lady with a history of
# intervascular coiling of her paraclinoid cavernous dysplastic right IC
# aneurysm ___ years ago and her recent diagnostic cerebral angiography confirmed
# a recanalization on this aneurysm and dysplastic segment at its cavernous
# segment.  She is here for a diagnostic cerebral angiography and fixing her
# right ICA dysplastic aneurysm using a flow diverting stent (pipeline stent).
#
# FIRST OPERATIVE SURGEON:  Dr. ___.
#
# FIRST ASSISTANT:  Dr. ___.
#
# SECOND ASSISTANT:  Dr. ___.
#
# OTHER ASSISTANTS:  Dr. ___ and ___
#
# PROCEDURE PERFORMED:  Diagnostic cerebral angiogram by catheterization
# injection into the right innominate artery, right common carotid artery, right
# internal carotid artery, spin angiogram by injecting into the right internal
# carotid artery and post processing of the data under supervision of concurrent
# ...

# %% [markdown]
# Let's find note count per icustay

# %%
note_counts_rad = rad_c_df.groupby('ICUSTAY_ID')['NOTE_ID'].count()
note_counts_dis = dis_c_df.groupby('ICUSTAY_ID')['NOTE_ID'].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 note_counts_rad = rad_c_df.groupby('ICUSTAY_ID')['NOTE_ID'].count()
# ----> 2 note_counts_dis = dis_c_df.groupby('ICUSTAY_ID')['NOTE_ID'].count()
#
# NameError: name 'dis_c_df' is not defined

# %%
summary_stats(note_counts_rad)
summary_stats(note_counts_dis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 summary_stats(note_counts_rad)
#       2 summary_stats(note_counts_dis)
#
# NameError: name 'summary_stats' is not defined

# %% [markdown]
# While there are 2 or 3 radiology reports per stay, there is almost always only 1 discharge report per stay.
# Thus, discharge notes can only be of limited use in real-time survival analysisby relying only on discharge reports from previous stays.
# Radiology reports, on the other hand, provide recent information on patient condition.

# %% [markdown]
# ## Further analysis
# Given that there is only one discharge per icustay, how many patients have multiple stays? In other words, how many patients would benefit from the inclusion of discharge notes?

# %%
trainpath = '/home/ugrads/a/aa_ron_su/BoXHED_Fuse/BoXHED_Fuse/JSS_SUBMISSION_NEW/data/till_end_mimic_iv_extra_features_train.csv'
mimic_iv_train = pd.read_csv(trainpath)

# %%
mimic_iv_train.rename(columns={'Icustay':'ICUSTAY_ID', 'subject':'SUBJECT_ID'}, inplace=True)

# %%
rad_c_df_w_subj = rad_c_df.merge(mimic_iv_train[['ICUSTAY_ID', 'SUBJECT_ID']], on='ICUSTAY_ID', how='inner')
dis_c_df_w_subj = dis_c_df.merge(mimic_iv_train[['ICUSTAY_ID', 'SUBJECT_ID']], on='ICUSTAY_ID', how='inner')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 rad_c_df_w_subj = rad_c_df.merge(mimic_iv_train[['ICUSTAY_ID', 'SUBJECT_ID']], on='ICUSTAY_ID', how='inner')
# ----> 2 dis_c_df_w_subj = dis_c_df.merge(mimic_iv_train[['ICUSTAY_ID', 'SUBJECT_ID']], on='ICUSTAY_ID', how='inner')
#
# NameError: name 'dis_c_df' is not defined

# %%
subject_note_counts_rad = rad_c_df_w_subj.groupby('SUBJECT_ID')['NOTE_ID'].nunique()
subject_note_counts_dis = dis_c_df_w_subj.groupby('SUBJECT_ID')['NOTE_ID'].nunique()

summary_stats(subject_note_counts_rad)
summary_stats(subject_note_counts_dis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 subject_note_counts_rad = rad_c_df_w_subj.groupby('SUBJECT_ID')['NOTE_ID'].nunique()
# ----> 2 subject_note_counts_dis = dis_c_df_w_subj.groupby('SUBJECT_ID')['NOTE_ID'].nunique()
#       4 summary_stats(subject_note_counts_rad)
#       5 summary_stats(subject_note_counts_dis)
#
# NameError: name 'dis_c_df_w_subj' is not defined

# %%
stay_note_counts_rad = rad_c_df.groupby('ICUSTAY_ID')['NOTE_ID'].nunique()
stay_note_counts_dis = dis_c_df.groupby('ICUSTAY_ID')['NOTE_ID'].nunique()

stay_note_counts_rad.mean(), stay_note_counts_dis.mean()
# Out:
# (2.8106152880817925, 1.0690287558685445)

# %%
stay_note_counts_rad_ALL = radiology[radiology.hadm_id.notna()].groupby('hadm_id')['note_id'].nunique()
stay_note_counts_dis_ALL = discharge[discharge.hadm_id.notna()].groupby('hadm_id')['note_id'].nunique()

stay_note_counts_rad_ALL.mean(), stay_note_counts_dis_ALL.mean()
# Out:
# (3.696702941841315, 1.0)

# %%
# Out:
# (2.8106152880817925, 1.0690287558685445)

# %%
# Out:
# (2.8106152880817925, 1.0690287558685445)

# %% [markdown]
# Even when grouping by subject, most patients only have 1 discharge summary.

# %%
subject_note_counts_rad = rad_c_df_w_subj.groupby('SUBJECT_ID')['NOTE_ID'].nunique()
subject_note_counts_dis = dis_c_df_w_subj.groupby('SUBJECT_ID')['NOTE_ID'].nunique()

print('radiology note counts by subject\n', subject_note_counts_rad)
print('radiology note counts by subject\n', subject_note_counts_dis)
# Out:
# radiology note counts by subject
#  SUBJECT_ID
# 10000032.0    1
# 10000980.0    1
# 10001217.0    3
# 10001725.0    1
# 10002013.0    2
#              ..
# 19999287.0    5
# 19999297.0    8
# 19999442.0    4
# 19999625.0    2
# 19999987.0    2
# Name: NOTE_ID, Length: 22725, dtype: int64
# radiology note counts by subject
#  SUBJECT_ID
# 10000032.0    1
# 10000980.0    1
# 10001217.0    1
# 10002013.0    1
# 10002155.0    1
#              ..
# 19998843.0    1
# 19999287.0    1
# 19999297.0    1
# 19999442.0    1
# 19999625.0    1
# Name: NOTE_ID, Length: 11042, dtype: int64

# %%
summary_stats(subject_note_counts_rad)
summary_stats(subject_note_counts_dis)
# Out:
# MEAN: 3.350847084708471
# MEDIAN: 3.0,
# MAX: 44
# MIN: 1
# MEAN: 1.3197790255388517
# MEDIAN: 1.0,
# MAX: 6
# MIN: 1

# %% [markdown]
# Even when grouping by subject, there most patients only have 1 discharge summary.
