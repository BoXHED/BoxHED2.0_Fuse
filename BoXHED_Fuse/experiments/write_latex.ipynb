# %%
# def dict_to_latex_table(data):
#     table = "\\begin{table}[H]\n"
#     table += "\\centering\n"
#     table += "\\caption{Description of Parameters}\n"
#     table += "\\begin{tabular}{lr}\n"
#     table += "\\toprule\n"
#     table += "\\textbf{Parameter} & \\textbf{Value} \\\\\n"
#     table += "\\midrule\n"
    
#     for key, value in data.items():
#         table += f"{key} & {value:.2f} \\\\\n"
    
#     table += "\\bottomrule\n"
#     table += "\\end{tabular}\n"
#     table += "\\end{table}\n"
    
#     return table

# # Example dictionary
# data = {'emb1': 5442.653525600001, 'Fraction inspired oxygen': 5389.572650710002, 'pH': 2459.99893202, 'time_since_note': 2256.9198417200005, 'Glascow coma scale total': 2236.6032985899997, 'O2 Flow': 1517.9635117500002, 'Respiratory Rate': 1387.7290609299998, 'Heart Rate': 1169.5126340399997, 'Oxygen saturation': 1115.03570546, 't_from_last_IV_t_end': 887.5050700599998, 'Respiratory rate': 799.3226050400001, 'Inspired O2 Fraction': 774.12080367, 'Height': 605.11602829, 'Systolic blood pressure': 516.0285338599999, 't_from_last_IV_t_start': 470.9190424499999, 'emb14': 436.3604744, 'emb32': 365.5180973, 'emb20': 325.096069, 'emb58': 304.4907223, 'O2 saturation pulseoxymetry': 277.489864962, 'emb56': 258.59559802, 'emb18': 253.684326, 'emb62': 225.9038998, 'emb54': 201.919434, 'Inspired Gas Temp.': 189.6728821, 'ETT Position Change': 173.9553985, 'Mean blood pressure': 172.73706441, 'emb47': 164.8619995, 'Age': 163.52770323000001, 'Respiratory Rate (Set)': 161.13598620000002, 'emb49': 158.578613, 'emb46': 141.533234, 'Peak Insp. Pressure': 128.29980472, 'Ventilator Tank #1': 123.84523, 'Total PEEP Level': 111.3233032, 'Weight': 109.84779831, 'emb17': 97.4031982, 'PSV Level': 83.50776680000001, 'emb15': 82.06286625, 'emb5': 80.77546689, 'Cuff Pressure': 77.2024537, 'Spont RR': 75.72802734, 'emb51': 74.6640625, 'PEEP set': 74.2122803, 'Capillary refill rate_nan': 74.20492555, 'emb63': 73.3699951, 'emb50': 70.3569335, 'Glucose': 68.3451424, 'P High (APRV)': 66.1138916, 'emb9': 64.2539673, 'Temperature': 64.24211308000001, 'emb29': 61.9515991, 'emb0': 53.9573975, 'ETT Re-taped': 53.474548299999995, 'Inspiratory Time': 42.9200287, 'emb43': 42.0498657, 'emb16': 40.2184296, 'emb30': 37.1951904, 'emb42': 35.36561967, 'Trach Care': 31.94819836, 'emb24': 31.4850082, 'Spont Vt': 31.0687866, 'Diastolic blood pressure': 29.67244335, 'emb53': 26.809082, 'emb57': 24.5544434, 'emb44': 23.671508789999997, 'Paw High': 23.5511475, 'emb21': 22.9627724, 'emb52': 22.845459, 'Expiratory Ratio': 22.767334, 'emb60': 21.8062134, 'emb33': 20.0803223, 'Small Volume Neb Dose #2': 17.39489751, 'emb2': 16.2803955, 'Vti High': 13.1568604, 'emb37': 12.3161392, 'O2 Flow (additional cannula)': 11.1266479, 'Minute Volume': 11.0333252, 'Respiratory Rate (Total)': 10.51379919, 'Cuff Volume (mL)': 9.21826172, 'PCV Level': 7.84777832, 'Tidal Volume (spontaneous)': 7.70436096, 'MDI #1 Puff': 7.0428772, 'emb11': 3.87926483, 'time': 3.31706238, 'Fspn High': 2.08849049, 'Respiratory Rate (spontaneous)': 2.07012463}

# # Convert dictionary to LaTeX table
# latex_table = dict_to_latex_table(data)

# # Print LaTeX table
# print(latex_table)

# %%
import pandas as pd

# Provided data
columns = ['ID', 't_start', 't_end',  'X0', 'X10', 'delta' ]
rows = [
    [1, 0.0100 ,0.0747 ,0.2655, 0.2059, 1] ,
    [1, 0.0747 ,0.1072 ,0.7829, 0.4380, 0] ,
    [1, 0.1072 ,0.1526 ,0.7570, 0.7789, 1],
    [2, 0.2066 ,0.2105 ,0.9618, 0.0859, 1],
    [2, 0.2345 ,0.2716 ,0.3586, 0.0242, 0]
]

# Create DataFrame
data = pd.DataFrame(rows, columns=columns)

# Add columns X1 through X9 and columns emb0 through emb63
for i in range(1, 10):
    data[f'X{i}'] = 0.5  # Example value (0.5)
    
for i in range(64):
    data[f'emb{i}'] = 0.5  # Example value (0.5)

# Print the updated DataFrame
print(data)

# %%
columns = ['ID', 't_start', 't_end',  'X0', 'X10', 'emb0', 'emb63', 'delta' ]
rows = [
[1, 0.0100 ,0.0747 ,0.2655, 0.2059, 0.412, 0.612, 1] ,
[1, 0.0747 ,0.1072 ,0.7829, 0.4380, 0.329, 0.103, 0 ] ,
[1, 0.1072 ,0.1526 ,0.7570, 0.7789, 0.101, 0.954, 1],
[2, 0.2066 ,0.2105 ,0.9618, 0.0859, 0.542, 0.658, 1],
[2, 0.2345 ,0.2716 ,0.3586, 0.0242, 0.412, 0.542, 0]]

data = pd.DataFrame(rows, columns = columns)

# %%
print(data.to_latex())
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
# {} &  ID &  t\_start &   t\_end &      X0 &     X10 &   emb0 &  emb63 &  delta \\
# \midrule
# 0 &   1 &   0.0100 &  0.0747 &  0.2655 &  0.2059 &  0.412 &  0.612 &      1 \\
# 1 &   1 &   0.0747 &  0.1072 &  0.7829 &  0.4380 &  0.329 &  0.103 &      0 \\
# 2 &   1 &   0.1072 &  0.1526 &  0.7570 &  0.7789 &  0.101 &  0.954 &      1 \\
# 3 &   2 &   0.2066 &  0.2105 &  0.9618 &  0.0859 &  0.542 &  0.658 &      1 \\
# 4 &   2 &   0.2345 &  0.2716 &  0.3586 &  0.0242 &  0.412 &  0.542 &      0 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_3277147/464907517.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data.to_latex())

# %%
data0 = {'Fraction inspired oxygen': 4979.0334299, 'pH': 4454.963160060002, 'Glascow coma scale total': 3914.350683570001, 'time_since_note': 2321.653103659, 'O2 Flow': 1563.954513492, 'Oxygen saturation': 1449.8602990599998, 'Age': 1368.1845946969997, 'Respiratory Rate': 1292.8332532100005, 'Heart Rate': 1251.0152590400003, 'Height': 1053.808594932, 'Respiratory rate': 894.5417887500003, 't_from_last_IV_t_end': 803.72444875, 'Systolic blood pressure': 579.102074581, 'Inspired O2 Fraction': 534.5270779780001, 't_from_last_IV_t_start': 367.56686414200004, 'O2 saturation pulseoxymetry': 272.58864751000004, 'Spont Vt': 244.17858890000002, 'Mean blood pressure': 205.99688422, 'Inspired Gas Temp.': 199.7924309, 'Cuff Pressure': 178.07759061000002, 'Glucose': 144.73707737959998, 'Weight': 144.107075248, 'ETT Position Change': 138.99418630000002, 'Peak Insp. Pressure': 127.97113032999998, 'Respiratory Rate (Set)': 122.41579441, 'time': 120.18247673100001, 'Tidal Volume (spontaneous)': 117.70747038, 'Capillary refill rate_nan': 110.79573058, 'Tidal Volume (observed)': 109.59218689000001, 'Temperature': 88.4158716, 'Expiratory Ratio': 75.330246, 'Minute Volume': 69.70325283, 'PSV Level': 62.4271928, 'Respiratory Rate (spontaneous)': 50.2918873, 'Vti High': 40.22330968, 'Spont RR': 39.78899765, 'O2 Flow (additional cannula)': 37.61951832, 'T Low (APRV)': 35.8928223, 'Total PEEP Level': 32.4257278, 'Diastolic blood pressure': 29.12706758, 'Small Volume Neb Dose #2': 24.0216064, 'MDI #1 Puff': 20.72467427, 'Mean Airway Pressure': 15.676471710000001, 'Paw High': 14.6408691, 'PEEP set': 14.3783207, 'Inspiratory Time': 14.33439542, 'Respiratory Rate (Total)': 13.82990836, 'Cuff Volume (mL)': 12.1542969, 'Tidal Volume (set)': 10.355835, 'Trach Care': 7.45432663, 'Fspn High': 7.417908199999999, 'Plateau Pressure': 6.80335712, 'BiPap IPAP': 5.82910919, 'Ventilator Tank #2': 5.4327774, 'Ventilator Tank #1': 4.13497162}
data1 = {'emb1': 5442.653525600001, 'Fraction inspired oxygen': 5389.572650710002, 'pH': 2459.99893202, 'time_since_note': 2256.9198417200005, 'Glascow coma scale total': 2236.6032985899997, 'O2 Flow': 1517.9635117500002, 'Respiratory Rate': 1387.7290609299998, 'Heart Rate': 1169.5126340399997, 'Oxygen saturation': 1115.03570546, 't_from_last_IV_t_end': 887.5050700599998, 'Respiratory rate': 799.3226050400001, 'Inspired O2 Fraction': 774.12080367, 'Height': 605.11602829, 'Systolic blood pressure': 516.0285338599999, 't_from_last_IV_t_start': 470.9190424499999, 'emb14': 436.3604744, 'emb32': 365.5180973, 'emb20': 325.096069, 'emb58': 304.4907223, 'O2 saturation pulseoxymetry': 277.489864962, 'emb56': 258.59559802, 'emb18': 253.684326, 'emb62': 225.9038998, 'emb54': 201.919434, 'Inspired Gas Temp.': 189.6728821, 'ETT Position Change': 173.9553985, 'Mean blood pressure': 172.73706441, 'emb47': 164.8619995, 'Age': 163.52770323000001, 'Respiratory Rate (Set)': 161.13598620000002, 'emb49': 158.578613, 'emb46': 141.533234, 'Peak Insp. Pressure': 128.29980472, 'Ventilator Tank #1': 123.84523, 'Total PEEP Level': 111.3233032, 'Weight': 109.84779831, 'emb17': 97.4031982, 'PSV Level': 83.50776680000001, 'emb15': 82.06286625, 'emb5': 80.77546689, 'Cuff Pressure': 77.2024537, 'Spont RR': 75.72802734, 'emb51': 74.6640625, 'PEEP set': 74.2122803, 'Capillary refill rate_nan': 74.20492555, 'emb63': 73.3699951, 'emb50': 70.3569335, 'Glucose': 68.3451424, 'P High (APRV)': 66.1138916, 'emb9': 64.2539673, 'Temperature': 64.24211308000001, 'emb29': 61.9515991, 'emb0': 53.9573975, 'ETT Re-taped': 53.474548299999995, 'Inspiratory Time': 42.9200287, 'emb43': 42.0498657, 'emb16': 40.2184296, 'emb30': 37.1951904, 'emb42': 35.36561967, 'Trach Care': 31.94819836, 'emb24': 31.4850082, 'Spont Vt': 31.0687866, 'Diastolic blood pressure': 29.67244335, 'emb53': 26.809082, 'emb57': 24.5544434, 'emb44': 23.671508789999997, 'Paw High': 23.5511475, 'emb21': 22.9627724, 'emb52': 22.845459, 'Expiratory Ratio': 22.767334, 'emb60': 21.8062134, 'emb33': 20.0803223, 'Small Volume Neb Dose #2': 17.39489751, 'emb2': 16.2803955, 'Vti High': 13.1568604, 'emb37': 12.3161392, 'O2 Flow (additional cannula)': 11.1266479, 'Minute Volume': 11.0333252, 'Respiratory Rate (Total)': 10.51379919, 'Cuff Volume (mL)': 9.21826172, 'PCV Level': 7.84777832, 'Tidal Volume (spontaneous)': 7.70436096, 'MDI #1 Puff': 7.0428772, 'emb11': 3.87926483, 'time': 3.31706238, 'Fspn High': 2.08849049, 'Respiratory Rate (spontaneous)': 2.07012463}
data2 = {'pH': 4954.90612988, 'Fraction inspired oxygen': 4834.27892644, 'time_since_note': 2367.14558303, 'Glascow coma scale total': 2032.4225844799996, 'Oxygen saturation': 1895.4418223799998, 'emb36': 1678.3312836, 'O2 Flow': 1369.758678176, 'Respiratory Rate': 1354.033981849, 'Heart Rate': 1282.05517301, 'emb12': 1160.5523074, 'Height': 903.1915969300001, 'emb20': 741.5800775999999, 'Respiratory rate': 734.740379375, 'emb45': 704.88800607, 'Inspired O2 Fraction': 605.0131740200001, 'Systolic blood pressure': 558.60374936, 't_from_last_IV_t_end': 533.7537151399998, 'emb34': 401.79831360000003, 't_from_last_IV_t_start': 352.00584219999996, 'Inspired Gas Temp.': 269.9944, 'Age': 257.34002173600004, 'emb26': 245.65786888, 'O2 saturation pulseoxymetry': 216.61524350000002, 'Spont Vt': 188.364624, 'Respiratory Rate (Set)': 183.11137403, 'time': 182.118066062, 'emb35': 151.5988767, 'emb13': 147.09154174, 'emb62': 144.90880592999997, 'emb56': 140.10197547, 'emb55': 137.340266629, 'Mean blood pressure': 120.82361984000002, 'emb61': 119.58874509999998, 'Tidal Volume (observed)': 108.4823989, 'Cuff Pressure': 107.51239394000001, 'emb18': 96.51939387, 'Cuff Volume (mL)': 92.7028198, 'MDI #1 Puff': 92.5840302, 'Glucose': 89.91792666, 'emb19': 85.10741807, 'emb28': 80.4485626, 'Capillary refill rate_nan': 80.4333496, 'ETT Position Change': 79.64078467, 'emb42': 76.30104065, 'emb15': 72.5828495, 'PEEP set': 69.84689325999999, 'emb8': 68.55929431, 'Weight': 66.79105, 'Peak Insp. Pressure': 61.9515991, 'Total PEEP Level': 57.93746659, 'Expiratory Ratio': 55.88517573, 'emb16': 52.704475380000005, 'emb10': 50.3661156, 'Minute Volume': 48.52206032, 'Diastolic blood pressure': 48.461936959999996, 'emb27': 47.4584465, 'emb14': 46.1060181, 'emb33': 42.8451233, 'emb30': 39.70968866, 'Spont RR': 39.66675566, 'Paw High': 37.96521, 'ETT Re-taped': 35.7702332, 'Ventilator Tank #1': 35.280797910000004, 'Temperature': 35.190289830000005, 'PSV Level': 33.6394043, 'emb0': 32.94011687, 'emb1': 31.9434452, 'Vti High': 31.797496820000003, 'emb63': 28.4835815, 'emb3': 27.326282499999998, 'emb37': 26.6227112, 'emb46': 26.252441400000002, 'Respiratory Rate (spontaneous)': 25.2114296, 'emb4': 22.3496552, 'Tidal Volume (spontaneous)': 21.89109827, 'O2 Flow (additional cannula)': 21.77125554, 'Mean Airway Pressure': 18.395713800000003, 'BiPap O2 Flow': 18.0413513, 'emb32': 17.96289257, 'Inspiratory Time': 14.657837879999999, 'emb53': 13.928688, 'MDI #2 Puff': 13.43636708, 'emb38': 10.5537605, 'emb43': 8.644321505999999, 'emb23': 8.32828522, 'emb7': 8.17930889, 'emb51': 6.907182690000001, 'emb5': 2.6631546, 'Fspn High': 2.35334921, 'emb29': 1.93527603, 'emb17': 0.349822164}

# %%
# data = data1
# keys = list(data.keys())
# values = list(data.values())

# keys = [k for k in keys if 'emb' in k]
# emb_values = [values[i] for i in range(len(keys)) if 'emb' in keys[i]]
# sum(emb_values), sum(values), sum(emb_values)/sum(values)
# Out:
# (31477.378747142004, 33439.167521351985, 0.9413326072499467)

# %%
import matplotlib.pyplot as plt

data = data0
keys = list(data.keys())
values = list(data.values())

def scale_to_range(values):
    min_val = min(values)
    max_val = max(values)
    scaled_values = [(x - min_val) / (max_val - min_val) for x in values]
    return scaled_values
values = scale_to_range(values)
print(values)

total_var_imp = sum(values)

# values = [values[i] for i in range(len(keys)) if 'emb' in keys[i]]
emb_var_imp = sum(values)

# keys = [k for k in keys if 'emb' in k]

if data == data0:
    values = [values[i] for i in range(len(keys)) if 'time_since_note' != keys[i]]
    keys = [k for k in keys if 'time_since_note' != k]

colors = ['tab:orange' if 'emb' in key or 'time_since_note' == key else 'tab:blue' for key in keys]

keys = keys[:20]
values = values[:20]
colors = colors[:20]

print(values)



# Create bar chart
plt.figure(figsize=(10, 8))  # Adjust the figure size as needed
plt.bar(keys, values, color=colors)
plt.ylim(0, 1.0)
# plt.text(0.95, 0.95, f'Total percentage contribution: {emb_var_imp/total_var_imp * 100:.1f}%', ha='right', va='top', transform=plt.gca().transAxes, fontsize=16)
plt.title('Embeddings relative variable importances for invasive ventilation onset', fontsize=16)
plt.xticks(rotation=90, fontsize=16)  # Rotate x-axis labels for better readability
# plt.xlabel('64 embedding features', fontsize=16)
# plt.xticks([],[])
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
# Out:
# [1.0, 0.8946570921527538, 0.7859890497748777, 0.4658422983853722, 0.31353796563946057, 0.2906039871092844, 0.2741864250127028, 0.2590401175817264, 0.2506343190472055, 0.21099397949820864, 0.1789798976998308, 0.16072478339717644, 0.11557363588075861, 0.10661365469183377, 0.07305312773110378, 0.05396163924576143, 0.048250958143775204, 0.0405760869880731, 0.03932893523773464, 0.03496405413069239, 0.02826230664579457, 0.02813567046680856, 0.02710793311882504, 0.02489219825258797, 0.023775525024664308, 0.0233266077859048, 0.02282910891798706, 0.021439786129197988, 0.021197862861800067, 0.016941230195307126, 0.014310900006713857, 0.013179823017467033, 0.011717268537005218, 0.009277961362845201, 0.007254085357247076, 0.007166784674903067, 0.006730699526996336, 0.006383617866037777, 0.005686700224587322, 0.005023639410851546, 0.003997395112035216, 0.0033346816601631008, 0.00231994686661209, 0.0021117812892270096, 0.0020590066643373247, 0.002050177282116087, 0.0019487707781983324, 0.001611957
# ...

# %%
import matplotlib.pyplot as plt

data = data1
keys = list(data.keys())
values = list(data.values())

def scale_to_range(values):
    min_val = min(values)
    max_val = max(values)
    scaled_values = [(x - min_val) / (max_val - min_val) for x in values]
    return scaled_values
values = scale_to_range(values)
print(values)

total_var_imp = sum(values)

values = [values[i] for i in range(len(keys)) if 'emb' in keys[i]]
keys = [k for k in keys if 'emb' in k]
emb_var_imp = sum(values)

colors = ['tab:orange' if 'emb' in key or 'time_since_note' == key else 'tab:blue' for key in keys]

keys = keys[:20]
values = values[:20]
colors = colors[:20]

print(values)



# Create bar chart
plt.figure(figsize=(10, 8))  # Adjust the figure size as needed
plt.bar(keys, values, color=colors)
plt.ylim(0, 1.0)
# plt.text(0.95, 0.95, f'Total percentage contribution: {emb_var_imp/total_var_imp * 100:.1f}%', ha='right', va='top', transform=plt.gca().transAxes, fontsize=16)
plt.title('Embeddings relative variable importances for invasive ventilation onset', fontsize=16)
plt.xticks(rotation=90, fontsize=16)  # Rotate x-axis labels for better readability
# plt.xlabel('64 embedding features', fontsize=16)
# plt.xticks([],[])
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
# Out:
# [1.0, 0.9902435325445916, 0.4517766986076854, 0.414449986501077, 0.41071572830987296, 0.2786269918865193, 0.25468940262048934, 0.2145803902577537, 0.2045673228043098, 0.1627463233579207, 0.14653804962678416, 0.14190586232027086, 0.1108421393838909, 0.09446751779200119, 0.08617622105313354, 0.07982422430884349, 0.06680312493788826, 0.059373401814299495, 0.05558606042434373, 0.050623199762528305, 0.047150361364603675, 0.046247650817215616, 0.04114150242234917, 0.03673306604111038, 0.03448210304735928, 0.03159316955592567, 0.03136923509886307, 0.029921768103210372, 0.029676519354746727, 0.029236912633604728, 0.0287668576759794, 0.0256338519404252, 0.023201497116558223, 0.022382729276475888, 0.020081151324786467, 0.019809947892864638, 0.017522582882012815, 0.01496854954111732, 0.01470297130372785, 0.014466342386363866, 0.013809608921095609, 0.013538603727105358, 0.013343042927539212, 0.013260003634378216, 0.013258651803249463, 0.013105188398966176, 0.012551376173706877, 0.012181601288969
# ...

# %%
list(data.keys())[24]
# Out:
# 'Inspired Gas Temp.'
